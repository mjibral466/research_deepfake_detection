# %% [markdown]
# <a href="https://colab.research.google.com/github/mjibral466/research_deepfake_detection/blob/main/deepfake_Detection_research.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torchvision
import cv2
import numpy as np
import matplotlib.pyplot as plt
